# %% [markdown]
# # Model Training
#
# Training multiple ML models for intrusion detection.

# %%
# Reproducibility
import numpy as np
import random

SEED = 42
np.random.seed(SEED)
random.seed(SEED)

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# NOTE: X_train_scaled, y_train are expected to be available
# Run preprocessing notebook first

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(probability=True, random_state=42)
}

trained_models = {}

for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    trained_models[name] = model

trained_models.keys()

# %%
# Sanity check: ensure consistent training size
print("Train samples:", X_train_scaled.shape[0])
print("Test samples:", X_test_scaled.shape[0])
